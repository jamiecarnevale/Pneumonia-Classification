# %%
from PIL import Image, ImageOps
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os, shutil
import time
import scipy
from scipy import ndimage
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import cv2
from keras import models
from keras import layers
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Now lets try and to make the results better

# %%
# Create a data generator
datagen2 = ImageDataGenerator(
    rescale=1./255, # normalize pixel values
    rotation_range=20, # randomly rotate images in the range
    zoom_range=0.2, # randomly zoom image 
    width_shift_range=0.2, # randomly shift images horizontally
    height_shift_range=0.2, # randomly shift images vertically 
    brightness_range=[0.7,1.3],  # slight changes in brightness
    horizontal_flip=True,
    vertical_flip=True
)
 # randomly flip images

# %%
# Use flow_from_directory to read images from folders
train_generator2 = datagen2.flow_from_directory(
        'CellData/chest_xray/train', # point to the parent directory
        target_size=(299, 299), # resize images to 299x299
        batch_size=32,
        class_mode='binary') # binary for two classes

# Similarly create validation and test generators
val_generator2 = datagen2.flow_from_directory(
        'CellData/chest_xray/val',
        target_size=(299, 299),
        batch_size=32,
        class_mode='binary')

test_generator2 = datagen2.flow_from_directory(
        'CellData/chest_xray/test',
        target_size=(299, 299),
        batch_size=32,
        class_mode='binary',
        shuffle=False)
# Out:
# Found 4098 images belonging to 2 classes.
# Found 879 images belonging to 2 classes.
# Found 879 images belonging to 2 classes.

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(64, (5, 5), activation='relu',
                        input_shape=(299 , 299,  3)))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Conv2D(64, (4, 4), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Conv2D(128, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))

model2.add(layers.Flatten())
model2.add(layers.Dense(128, activation='relu'))
model2.add(layers.Dense(256, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

model2.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['acc'])
# Out:
# 2023-07-14 15:22:22.568996: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-14 15:22:22.569204: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M2 Pro

# %%
from collections import Counter
import numpy as np

# Get class distribution
counter = Counter(train_generator2.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}                     

print(counter)
print(max_val)
print(class_weights)
# Out:
# Counter({1: 2991, 0: 1107})
# 2991.0
# {0: 2.7018970189701896, 1: 1.0}

# %%
epochs = 160

steps_per_epoch2 = np.ceil(train_generator2.samples / train_generator2.batch_size)
validation_steps2 = np.ceil(val_generator2.samples / val_generator2.batch_size)

history = model2.fit(
    train_generator2,
    steps_per_epoch=int(steps_per_epoch2),
    epochs=epochs,
    validation_data=val_generator2,
    validation_steps=int(validation_steps2),
    class_weight=class_weights)
# Out:
# Epoch 1/160
# 2023-07-14 15:22:25.784489: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-07-14 15:22:25.954894: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 129/129 [==============================] - ETA: 0s - loss: 0.7730 - acc: 0.7360
# 2023-07-14 15:23:25.129640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 129/129 [==============================] - 73s 553ms/step - loss: 0.7730 - acc: 0.7360 - val_loss: 0.4002 - val_acc: 0.7861
# Epoch 2/160
# 129/129 [==============================] - 72s 562ms/step - loss: 0.6345 - acc: 0.8077 - val_loss: 0.3507 - val_acc: 0.8430
# Epoch 3/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.5697 - acc: 0.8277 - val_loss: 0.4159 - val_acc: 0.8168
# Epoch 4/160
# 129/129 [==============================] - 71s 543ms/step - loss: 0.4968 - acc: 0.8602 - val_loss: 0.2893 - val_acc: 0.8953
# Epoch 5/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.5667 - acc: 0.8387 - val_loss: 0.2910 - val_acc: 0.8771
# Epoch 6/160
# 129/129 [==============================] - 72s 555ms/step - loss: 0.4804 - acc: 0.8621 - val_loss: 0.2552 - val_acc: 0.8987
# Epoch 7/160
# 129/129 [==============================] - 73s 561ms/step - loss: 0.4634 - acc: 0.8646 - val_loss: 0.2488 - val_acc: 0.8976
# Epoch 8/160
# 129/129 [==============================] - 72s 558ms/step - loss: 0.4571 - acc: 0.8716 - val_loss: 0.3021 - val_acc: 0.8726
# Epoch 9/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.4503 - acc: 0.8653 - val_loss: 0.2642 - val_acc: 0.9033
# Epoch 10/160
# 129/129 [==============================] - 72s 558ms/step - loss: 0.4436 - acc: 0.8660 - val_loss: 0.2402 - val_acc: 0.9101
# Epoch 11/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.4320 - acc: 0.8731 - val_loss: 0.4446 - val_acc: 0.8146
# Epoch 12/160
# 129/129 [==============================] - 72s 555ms/step - loss: 0.5010 - acc: 0.8546 - val_loss: 0.2415 - val_acc: 0.8976
# Epoch 13/160
# 129/129 [==============================] - 72s 558ms/step - loss: 0.4042 - acc: 0.8807 - val_loss: 0.2195 - val_acc: 0.9067
# Epoch 14/160
# 129/129 [==============================] - 72s 555ms/step - loss: 0.3905 - acc: 0.8890 - val_loss: 0.2551 - val_acc: 0.8999
# Epoch 15/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.3864 - acc: 0.8892 - val_loss: 0.2351 - val_acc: 0.9170
# Epoch 16/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.4024 - acc: 0.8807 - val_loss: 0.2416 - val_acc: 0.8976
# Epoch 17/160
# 129/129 [==============================] - 72s 552ms/step - loss: 0.3915 - acc: 0.8929 - val_loss: 0.2753 - val_acc: 0.8851
# Epoch 18/160
# 129/129 [==============================] - 73s 560ms/step - loss: 0.3890 - acc: 0.8868 - val_loss: 0.2689 - val_acc: 0.8931
# Epoch 19/160
# 129/129 [==============================] - 72s 558ms/step - loss: 0.3535 - acc: 0.8956 - val_loss: 0.2886 - val_acc: 0.8919
# Epoch 20/160
# 129/129 [==============================] - 74s 571ms/step - loss: 0.4162 - acc: 0.8821 - val_loss: 0.2511 - val_acc: 0.8953
# Epoch 21/160
# 129/129 [==============================] - 74s 572ms/step - loss: 0.3717 - acc: 0.8875 - val_loss: 0.2690 - val_acc: 0.9101
# Epoch 22/160
# 129/129 [==============================] - 74s 573ms/step - loss: 0.3491 - acc: 0.8943 - val_loss: 0.2334 - val_acc: 0.9090
# Epoch 23/160
# 129/129 [==============================] - 74s 569ms/step - loss: 0.3561 - acc: 0.8882 - val_loss: 0.2532 - val_acc: 0.9090
# Epoch 24/160
# 129/129 [==============================] - 74s 569ms/step - loss: 0.3317 - acc: 0.9068 - val_loss: 0.3457 - val_acc: 0.8714
# Epoch 25/160
# 129/129 [==============================] - 75s 575ms/step - loss: 0.3341 - acc: 0.8992 - val_loss: 0.2004 - val_acc: 0.9170
# Epoch 26/160
# 129/129 [==============================] - 74s 572ms/step - loss: 0.3215 - acc: 0.9078 - val_loss: 0.2570 - val_acc: 0.8953
# Epoch 27/160
# 129/129 [==============================] - 73s 559ms/step - loss: 0.3315 - acc: 0.9053 - val_loss: 0.1766 - val_acc: 0.9283
# Epoch 28/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.3031 - acc: 0.9134 - val_loss: 0.2722 - val_acc: 0.8896
# Epoch 29/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.3176 - acc: 0.9061 - val_loss: 0.2564 - val_acc: 0.8987
# Epoch 30/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.3246 - acc: 0.9043 - val_loss: 0.3609 - val_acc: 0.8703
# Epoch 31/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.3411 - acc: 0.8960 - val_loss: 0.2293 - val_acc: 0.9090
# Epoch 32/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.3148 - acc: 0.9078 - val_loss: 0.2282 - val_acc: 0.9044
# Epoch 33/160
# 129/129 [==============================] - 71s 553ms/step - loss: 0.3227 - acc: 0.9095 - val_loss: 0.2613 - val_acc: 0.9010
# Epoch 34/160
# 129/129 [==============================] - 70s 543ms/step - loss: 0.3308 - acc: 0.9092 - val_loss: 0.2000 - val_acc: 0.9135
# Epoch 35/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2869 - acc: 0.9219 - val_loss: 0.2112 - val_acc: 0.9215
# Epoch 36/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2974 - acc: 0.9161 - val_loss: 0.1644 - val_acc: 0.9386
# Epoch 37/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2866 - acc: 0.9246 - val_loss: 0.1872 - val_acc: 0.9181
# Epoch 38/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2870 - acc: 0.9190 - val_loss: 0.2071 - val_acc: 0.9215
# Epoch 39/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.3715 - acc: 0.8868 - val_loss: 0.2457 - val_acc: 0.9022
# Epoch 40/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.3280 - acc: 0.8992 - val_loss: 0.1748 - val_acc: 0.9238
# Epoch 41/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.3199 - acc: 0.9063 - val_loss: 0.1864 - val_acc: 0.9238
# Epoch 42/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.3131 - acc: 0.9143 - val_loss: 0.1632 - val_acc: 0.9352
# Epoch 43/160
# 129/129 [==============================] - 72s 554ms/step - loss: 0.3074 - acc: 0.9136 - val_loss: 0.1827 - val_acc: 0.9238
# Epoch 44/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2568 - acc: 0.9292 - val_loss: 0.2329 - val_acc: 0.9056
# Epoch 45/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2743 - acc: 0.9190 - val_loss: 0.2241 - val_acc: 0.9056
# Epoch 46/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2861 - acc: 0.9234 - val_loss: 0.2471 - val_acc: 0.9067
# Epoch 47/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2883 - acc: 0.9151 - val_loss: 0.3049 - val_acc: 0.8783
# Epoch 48/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.3231 - acc: 0.9029 - val_loss: 0.1933 - val_acc: 0.9306
# Epoch 49/160
# 129/129 [==============================] - 71s 543ms/step - loss: 0.2581 - acc: 0.9263 - val_loss: 0.1869 - val_acc: 0.9283
# Epoch 50/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2775 - acc: 0.9190 - val_loss: 0.1759 - val_acc: 0.9306
# Epoch 51/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2654 - acc: 0.9265 - val_loss: 0.1788 - val_acc: 0.9363
# Epoch 52/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2616 - acc: 0.9256 - val_loss: 0.1608 - val_acc: 0.9454
# Epoch 53/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2626 - acc: 0.9322 - val_loss: 0.2727 - val_acc: 0.9067
# Epoch 54/160
# 129/129 [==============================] - 72s 558ms/step - loss: 0.2756 - acc: 0.9263 - val_loss: 0.2016 - val_acc: 0.9226
# Epoch 55/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2717 - acc: 0.9222 - val_loss: 0.1809 - val_acc: 0.9261
# Epoch 56/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2544 - acc: 0.9280 - val_loss: 0.1769 - val_acc: 0.9215
# Epoch 57/160
# 129/129 [==============================] - 72s 554ms/step - loss: 0.2785 - acc: 0.9217 - val_loss: 0.1994 - val_acc: 0.9283
# Epoch 58/160
# 129/129 [==============================] - 72s 554ms/step - loss: 0.2636 - acc: 0.9236 - val_loss: 0.1595 - val_acc: 0.9443
# Epoch 59/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2594 - acc: 0.9280 - val_loss: 0.1660 - val_acc: 0.9317
# Epoch 60/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2632 - acc: 0.9290 - val_loss: 0.1368 - val_acc: 0.9454
# Epoch 61/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2570 - acc: 0.9265 - val_loss: 0.1890 - val_acc: 0.9283
# Epoch 62/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2669 - acc: 0.9261 - val_loss: 0.1851 - val_acc: 0.9306
# Epoch 63/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2461 - acc: 0.9317 - val_loss: 0.2015 - val_acc: 0.9283
# Epoch 64/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2571 - acc: 0.9275 - val_loss: 0.1698 - val_acc: 0.9374
# Epoch 65/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2690 - acc: 0.9258 - val_loss: 0.1743 - val_acc: 0.9306
# Epoch 66/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2400 - acc: 0.9366 - val_loss: 0.1680 - val_acc: 0.9374
# Epoch 67/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2739 - acc: 0.9226 - val_loss: 0.2234 - val_acc: 0.9215
# Epoch 68/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2556 - acc: 0.9278 - val_loss: 0.2082 - val_acc: 0.9249
# Epoch 69/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2476 - acc: 0.9322 - val_loss: 0.1581 - val_acc: 0.9363
# Epoch 70/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2670 - acc: 0.9280 - val_loss: 0.1848 - val_acc: 0.9352
# Epoch 71/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2522 - acc: 0.9268 - val_loss: 0.2148 - val_acc: 0.9192
# Epoch 72/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2360 - acc: 0.9319 - val_loss: 0.1992 - val_acc: 0.9317
# Epoch 73/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2481 - acc: 0.9327 - val_loss: 0.1886 - val_acc: 0.9386
# Epoch 74/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2527 - acc: 0.9317 - val_loss: 0.1960 - val_acc: 0.9363
# Epoch 75/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2557 - acc: 0.9356 - val_loss: 0.2264 - val_acc: 0.9215
# Epoch 76/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2541 - acc: 0.9280 - val_loss: 0.1992 - val_acc: 0.9272
# Epoch 77/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2299 - acc: 0.9361 - val_loss: 0.1492 - val_acc: 0.9545
# Epoch 78/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2608 - acc: 0.9280 - val_loss: 0.3084 - val_acc: 0.8908
# Epoch 79/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2540 - acc: 0.9285 - val_loss: 0.1394 - val_acc: 0.9499
# Epoch 80/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2552 - acc: 0.9317 - val_loss: 0.1641 - val_acc: 0.9454
# Epoch 81/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2229 - acc: 0.9368 - val_loss: 0.1550 - val_acc: 0.9397
# Epoch 82/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2395 - acc: 0.9331 - val_loss: 0.1561 - val_acc: 0.9408
# Epoch 83/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2440 - acc: 0.9356 - val_loss: 0.1821 - val_acc: 0.9420
# Epoch 84/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2355 - acc: 0.9348 - val_loss: 0.1655 - val_acc: 0.9408
# Epoch 85/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2402 - acc: 0.9344 - val_loss: 0.1621 - val_acc: 0.9431
# Epoch 86/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2279 - acc: 0.9363 - val_loss: 0.1484 - val_acc: 0.9488
# Epoch 87/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2396 - acc: 0.9380 - val_loss: 0.2202 - val_acc: 0.9192
# Epoch 88/160
# 129/129 [==============================] - 72s 554ms/step - loss: 0.2288 - acc: 0.9405 - val_loss: 0.1704 - val_acc: 0.9397
# Epoch 89/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2391 - acc: 0.9356 - val_loss: 0.1811 - val_acc: 0.9340
# Epoch 90/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2359 - acc: 0.9351 - val_loss: 0.1526 - val_acc: 0.9431
# Epoch 91/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2356 - acc: 0.9402 - val_loss: 0.1571 - val_acc: 0.9465
# Epoch 92/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2560 - acc: 0.9307 - val_loss: 0.1693 - val_acc: 0.9408
# Epoch 93/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2234 - acc: 0.9366 - val_loss: 0.1416 - val_acc: 0.9465
# Epoch 94/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2361 - acc: 0.9327 - val_loss: 0.1676 - val_acc: 0.9363
# Epoch 95/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2477 - acc: 0.9351 - val_loss: 0.1628 - val_acc: 0.9408
# Epoch 96/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2235 - acc: 0.9385 - val_loss: 0.1578 - val_acc: 0.9454
# Epoch 97/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2379 - acc: 0.9405 - val_loss: 0.2019 - val_acc: 0.9363
# Epoch 98/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2414 - acc: 0.9368 - val_loss: 0.1499 - val_acc: 0.9488
# Epoch 99/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2292 - acc: 0.9361 - val_loss: 0.1773 - val_acc: 0.9329
# Epoch 100/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2249 - acc: 0.9348 - val_loss: 0.1467 - val_acc: 0.9488
# Epoch 101/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2297 - acc: 0.9370 - val_loss: 0.1453 - val_acc: 0.9511
# Epoch 102/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2205 - acc: 0.9400 - val_loss: 0.1290 - val_acc: 0.9545
# Epoch 103/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2166 - acc: 0.9409 - val_loss: 0.1792 - val_acc: 0.9317
# Epoch 104/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2321 - acc: 0.9351 - val_loss: 0.1923 - val_acc: 0.9329
# Epoch 105/160
# 129/129 [==============================] - 72s 552ms/step - loss: 0.2594 - acc: 0.9268 - val_loss: 0.1412 - val_acc: 0.9443
# Epoch 106/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2386 - acc: 0.9390 - val_loss: 0.1978 - val_acc: 0.9261
# Epoch 107/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2258 - acc: 0.9383 - val_loss: 0.1427 - val_acc: 0.9454
# Epoch 108/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.2216 - acc: 0.9395 - val_loss: 0.1639 - val_acc: 0.9363
# Epoch 109/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2130 - acc: 0.9439 - val_loss: 0.1870 - val_acc: 0.9386
# Epoch 110/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2191 - acc: 0.9392 - val_loss: 0.1368 - val_acc: 0.9545
# Epoch 111/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2116 - acc: 0.9409 - val_loss: 0.1628 - val_acc: 0.9477
# Epoch 112/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2226 - acc: 0.9390 - val_loss: 0.1711 - val_acc: 0.9340
# Epoch 113/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2391 - acc: 0.9329 - val_loss: 0.1499 - val_acc: 0.9488
# Epoch 114/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2405 - acc: 0.9375 - val_loss: 0.1765 - val_acc: 0.9295
# Epoch 115/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2288 - acc: 0.9383 - val_loss: 0.1354 - val_acc: 0.9522
# Epoch 116/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2327 - acc: 0.9339 - val_loss: 0.1684 - val_acc: 0.9443
# Epoch 117/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2475 - acc: 0.9344 - val_loss: 0.1754 - val_acc: 0.9386
# Epoch 118/160
# 129/129 [==============================] - 72s 552ms/step - loss: 0.2259 - acc: 0.9388 - val_loss: 0.1682 - val_acc: 0.9443
# Epoch 119/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2349 - acc: 0.9400 - val_loss: 0.1400 - val_acc: 0.9511
# Epoch 120/160
# 129/129 [==============================] - 72s 551ms/step - loss: 0.2239 - acc: 0.9375 - val_loss: 0.1841 - val_acc: 0.9420
# Epoch 121/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2170 - acc: 0.9419 - val_loss: 0.1530 - val_acc: 0.9465
# Epoch 122/160
# 129/129 [==============================] - 71s 551ms/step - loss: 0.2224 - acc: 0.9385 - val_loss: 0.1926 - val_acc: 0.9352
# Epoch 123/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2250 - acc: 0.9378 - val_loss: 0.1321 - val_acc: 0.9499
# Epoch 124/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2158 - acc: 0.9417 - val_loss: 0.1683 - val_acc: 0.9397
# Epoch 125/160
# 129/129 [==============================] - 71s 544ms/step - loss: 0.2118 - acc: 0.9453 - val_loss: 0.1582 - val_acc: 0.9408
# Epoch 126/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2266 - acc: 0.9388 - val_loss: 0.1497 - val_acc: 0.9477
# Epoch 127/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2235 - acc: 0.9348 - val_loss: 0.1580 - val_acc: 0.9352
# Epoch 128/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2083 - acc: 0.9449 - val_loss: 0.1663 - val_acc: 0.9374
# Epoch 129/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.2249 - acc: 0.9427 - val_loss: 0.1988 - val_acc: 0.9306
# Epoch 130/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2182 - acc: 0.9405 - val_loss: 0.2154 - val_acc: 0.9317
# Epoch 131/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2183 - acc: 0.9441 - val_loss: 0.1311 - val_acc: 0.9522
# Epoch 132/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2291 - acc: 0.9339 - val_loss: 0.1557 - val_acc: 0.9420
# Epoch 133/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2102 - acc: 0.9407 - val_loss: 0.1180 - val_acc: 0.9568
# Epoch 134/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2071 - acc: 0.9439 - val_loss: 0.1750 - val_acc: 0.9374
# Epoch 135/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2302 - acc: 0.9363 - val_loss: 0.1311 - val_acc: 0.9465
# Epoch 136/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2121 - acc: 0.9444 - val_loss: 0.1631 - val_acc: 0.9465
# Epoch 137/160
# 129/129 [==============================] - 72s 555ms/step - loss: 0.2256 - acc: 0.9373 - val_loss: 0.1670 - val_acc: 0.9443
# Epoch 138/160
# 129/129 [==============================] - 72s 555ms/step - loss: 0.2207 - acc: 0.9429 - val_loss: 0.1442 - val_acc: 0.9488
# Epoch 139/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2243 - acc: 0.9424 - val_loss: 0.1762 - val_acc: 0.9352
# Epoch 140/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2073 - acc: 0.9434 - val_loss: 0.1514 - val_acc: 0.9477
# Epoch 141/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2171 - acc: 0.9414 - val_loss: 0.1739 - val_acc: 0.9329
# Epoch 142/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2186 - acc: 0.9449 - val_loss: 0.1621 - val_acc: 0.9443
# Epoch 143/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2143 - acc: 0.9417 - val_loss: 0.1504 - val_acc: 0.9477
# Epoch 144/160
# 129/129 [==============================] - 71s 545ms/step - loss: 0.2023 - acc: 0.9439 - val_loss: 0.1134 - val_acc: 0.9613
# Epoch 145/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.1931 - acc: 0.9473 - val_loss: 0.1336 - val_acc: 0.9488
# Epoch 146/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2201 - acc: 0.9383 - val_loss: 0.1444 - val_acc: 0.9454
# Epoch 147/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.1958 - acc: 0.9446 - val_loss: 0.1502 - val_acc: 0.9488
# Epoch 148/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2157 - acc: 0.9414 - val_loss: 0.1379 - val_acc: 0.9488
# Epoch 149/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2167 - acc: 0.9414 - val_loss: 0.1557 - val_acc: 0.9443
# Epoch 150/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2569 - acc: 0.9300 - val_loss: 0.2109 - val_acc: 0.9272
# Epoch 151/160
# 129/129 [==============================] - 71s 550ms/step - loss: 0.2457 - acc: 0.9290 - val_loss: 0.1584 - val_acc: 0.9374
# Epoch 152/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.2291 - acc: 0.9322 - val_loss: 0.1566 - val_acc: 0.9408
# Epoch 153/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2180 - acc: 0.9412 - val_loss: 0.1510 - val_acc: 0.9454
# Epoch 154/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2134 - acc: 0.9424 - val_loss: 0.1824 - val_acc: 0.9317
# Epoch 155/160
# 129/129 [==============================] - 71s 549ms/step - loss: 0.2111 - acc: 0.9434 - val_loss: 0.1359 - val_acc: 0.9511
# Epoch 156/160
# 129/129 [==============================] - 72s 553ms/step - loss: 0.2053 - acc: 0.9417 - val_loss: 0.1616 - val_acc: 0.9420
# Epoch 157/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.1966 - acc: 0.9480 - val_loss: 0.1426 - val_acc: 0.9511
# Epoch 158/160
# 129/129 [==============================] - 71s 548ms/step - loss: 0.2037 - acc: 0.9405 - val_loss: 0.1603 - val_acc: 0.9374
# Epoch 159/160
# 129/129 [==============================] - 71s 547ms/step - loss: 0.2107 - acc: 0.9441 - val_loss: 0.1394 - val_acc: 0.9499
# Epoch 160/160
# 129/129 [==============================] - 71s 546ms/step - loss: 0.1856 - acc: 0.9468 - val_loss: 0.1406 - val_acc: 0.9454

# %%
results_train = model2.evaluate(train_generator2)
results_test = model2.evaluate(val_generator2)
print('Training set performance:', results_train)
print('Validation set performance:', results_test)
# Out:
# 129/129 [==============================] - 59s 448ms/step - loss: 0.1273 - acc: 0.9546
# 28/28 [==============================] - 14s 480ms/step - loss: 0.1214 - acc: 0.9579
# Training set performance: [0.12731137871742249, 0.9546120166778564]
# Validation set performance: [0.1214025616645813, 0.9579067826271057]

# %%
results_train = model2.evaluate(train_generator2)
results_test = model2.evaluate(val_generator2)
print('Training set performance:', results_train)
print('Validation set performance:', results_test)
# Out:
# 129/129 [==============================] - 57s 435ms/step - loss: 0.1276 - acc: 0.9502
# 28/28 [==============================] - 13s 458ms/step - loss: 0.1274 - acc: 0.9568
# Training set performance: [0.12760810554027557, 0.9502196311950684]
# Validation set performance: [0.1274494230747223, 0.9567691087722778]

# %%
model2.save('modelv11weighted.h5')  # creates a HDF5 file 'my_model.h5'

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 295, 295, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 147, 147, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 144, 144, 64)      65600
#
#  max_pooling2d_1 (MaxPooling  (None, 72, 72, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 70, 70, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 35, 35, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 156800)            0
#
#  dense (Dense)               (None, 128)               20070528
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 20,248,129
# Trainable params: 20,248,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Generate predictions
y_pred = model2.predict(test_generator2)
# Out:
# 2023-07-14 19:21:40.248085: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 13s 455ms/step

# %%
y_pred = (y_pred > 0.5).astype(int)
y_true = test_generator2.classes

# %%
cm = confusion_matrix(y_true, y_pred)

# Visualize the confusion matrix using Seaborn
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %%
from sklearn.metrics import classification_report


# Convert continuous values to binary
y_pred_binary = [1 if p>=0.5 else 0 for p in y_pred]

tn, fp, fn, tp = confusion_matrix(y_true, y_pred_binary).ravel()

specificity = tn / (tn+fp)
print("Specificity: ", specificity)



print(classification_report(y_true, y_pred_binary, target_names=test_generator2.class_indices.keys()))
# Out:
# Specificity:  0.9243697478991597
#               precision    recall  f1-score   support
#
#       NORMAL       0.89      0.92      0.91       238
#    PNEUMONIA       0.97      0.96      0.96       641
#
#     accuracy                           0.95       879
#    macro avg       0.93      0.94      0.93       879
# weighted avg       0.95      0.95      0.95       879

# %%
# Convert probabilities into binary outputs
y_pred_binary = [1 if y >= 0.5 else 0 for y in y_pred]

# Then use these binary predictions to compute the classification report
report = classification_report(y_true, y_pred_binary, target_names=test_generator2.class_indices.keys(), output_dict=True)

# Convert the report to a DataFrame
df_report = pd.DataFrame(report).transpose()

# Plot the heatmap
plt.figure(figsize=(10, 6)) 
sns.heatmap(df_report.iloc[:-1, :-1], annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Classification Report")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Assuming val_generator2 is your validation generator
test_generator2.reset()

# Generate predictions
y_pred_probs = model2.predict(test_generator2)

# Get true labels
y_true = test_generator2.classes

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred_probs)

# Compute AUC
auc = roc_auc_score(y_true, y_pred_probs)
print("AUC: ", auc)
# Plot ROC curve
plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 28/28 [==============================] - 12s 431ms/step
# AUC:  0.987886574286501

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing import image



# Load the image
img = image.load_img('CellData/chest_xray/train/PNEUMONIA/BACTERIA-9074730-0001.jpeg', target_size=(299, 299))

# Preprocess the image
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_preprocessed = img_array/255.

# %%
predictions = model2.predict(img_preprocessed)
# Out:
# 2023-07-14 19:22:10.077847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 465ms/step

# %%
if predictions[0] > 0.5:
    print('The model predicts this image is of a PNEUMONIA case.')
else:
    print('The model predicts this image is of a NORMAL case.')
# Out:
# The model predicts this image is of a PNEUMONIA case.

# %% [markdown]
# ## not bad, not as good as best model
